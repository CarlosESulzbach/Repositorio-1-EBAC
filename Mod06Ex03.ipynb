# %% [markdown]
# # Módulo 6 tarefa 3
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esse arquivo.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %matplotlib notebook

# %%
bd = pd.read_csv('b1abb33c4f.csv', sep = ',')
bd.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %% [markdown]
# #### 2) Categorize a variável APGAR5 conforme as seguintes quebras:
#
# - 0 a 3: 'asfixia grave'
# - 4 a 5: 'asfixia moderada'
# - 6 a 7: 'asfixia leve'
# - 8 a 10: 'normal'

# %%
bd.loc[bd['APGAR5'] <= 3, 'APGAR_CAT'] = 'asfixia grave'
bd.loc[(bd['APGAR5'] == 3) | (bd['APGAR5'] == 5), 'APGAR_CAT'] = 'asfixia moderada'
bd.loc[(bd['APGAR5'] == 6) | (bd['APGAR5'] == 7), 'APGAR_CAT'] = 'asfixia leve'
bd.loc[bd['APGAR5'] >= 8, 'APGAR_CAT'] = 'normal'

bd.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  CONTADOR  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...         1
# 1      8 a 11 anos    999992.0         1.0         0.0  ...         2
# 2      8 a 11 anos    513205.0         2.0         0.0  ...         3
# 3  12 anos ou mais    231205.0         0.0         0.0  ...         4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...         5
#
#   munResStatus munResTipo               munResNome  munResUf munResLat  \
# 0        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia -11.93554
# ...

# %%
bd.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
# ...

# %% [markdown]
# #### 3) Monte um gráfico comparando a distribuição de APGAR5 por sexo para cada grupo de tempo de gestação (GESTACAO).

# %%
sns.scatterplot(x = 'APGAR5'
               , y = 'GESTACAO'
               , data = bd
               , alpha = .5
               , hue = 'SEXO')
# Out:
# <AxesSubplot:xlabel='APGAR5', ylabel='GESTACAO'>

# %% [markdown]
# ####  4) Monte uma tabela cruzada com APGAR5 nas colunas e GESTACAO nas linhas

# %%
freq = pd.crosstab(bd['GESTACAO'], bd['APGAR_CAT'])
freq
# Out:
# APGAR_CAT            asfixia grave  asfixia leve  asfixia moderada  normal
# GESTACAO
# 22 a 27 semanas                 15            12                 6      51
# 28 a 31 semanas                  2            18                 8     129
# 32 a 36 semanas                  6            73                13    2134
# 37 a 41 semanas                 28           196                26   22266
# 42 semanas e mais                1             6                 1     690
# Menos de 22 semanas              2             1                 0       4

# %% [markdown]
# ####  5) Da tabela cruzada do intem anterior, calcule os percentuais de linha. Ou seja, a distribuição da variável APGAR5 para cada classe de GESTACAO dado.

# %%
freq_pct = freq.div(freq.sum(axis = 1), axis = 0)
freq_pct
# Out:
# APGAR_CAT            asfixia grave  asfixia leve  asfixia moderada    normal
# GESTACAO
# 22 a 27 semanas           0.178571      0.142857          0.071429  0.607143
# 28 a 31 semanas           0.012739      0.114650          0.050955  0.821656
# 32 a 36 semanas           0.002695      0.032794          0.005840  0.958670
# 37 a 41 semanas           0.001244      0.008705          0.001155  0.988897
# 42 semanas e mais         0.001433      0.008596          0.001433  0.988539
# Menos de 22 semanas       0.285714      0.142857          0.000000  0.571429

# %% [markdown]
# ####  6) Os médicos costumam classificar parto prematuro quando a gestação tem menos que 37 semanas. Faça um gráfico de barras da tabela cruzada acima e conclua se você acha que este conjunto de dados corrobora ou não com a afirmação dos médicos.

# %%
freq_pct.plot.bar()
# Out:
# <AxesSubplot:xlabel='GESTACAO'>

# %% [markdown]
# Pela visualização do gráfico e da tabela, é possível perceber que os piores casos de asfixia grave ou asfixia moderada ocorrem com mais frequência com menos de 37 semanas

# %% [markdown]
# #### 7) Veja se há relação entre APGAR5 e o peso do bebê. Isso pode ser feito de diversas formas. Fique à vontade para escolher a melhor maneira na sua opinião, ou até testar mais de um dos gráficos que vimos. Fique à vontade também para consultar a documentação e utilizar algum outro recurso se achar conveniente.

# %%
sns.scatterplot(x = 'APGAR_CAT'
               , y = 'PESO'
               , data = bd
               , alpha = .5
#               , hue = 'SEXO'
               )
# Out:
# <AxesSubplot:xlabel='APGAR_CAT', ylabel='PESO'>
